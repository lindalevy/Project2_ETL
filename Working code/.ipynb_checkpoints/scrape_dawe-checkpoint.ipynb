# %%
from splinter import Browser
from bs4 import BeautifulSoup as bs
import time
from webdriver_manager.chrome import ChromeDriverManager

# %%
executable_path = {'executable_path': ChromeDriverManager().install()}
browser = Browser('chrome', **executable_path, headless=False)
# Out:
# [WDM] - ====== WebDriver manager ======
# [WDM] - Current google-chrome version is 88.0.4324
# [WDM] - Get LATEST driver version for 88.0.4324
# [WDM] - Driver [C:\Users\franz\.wdm\drivers\chromedriver\win32\88.0.4324.96\chromedriver.exe] found in cache

# %%
# Visit DAWE
url = "https://www.agriculture.gov.au/import/online-services/delivery-postcode/summary#victoria"
browser.visit(url)

# %%
# Scrape page into Soup
html = browser.html
soup = bs(html, "html.parser")

# %%
# Get the postcode table/list
postcodes = soup.find_all("strong")
type(postcodes)
# Out:
# bs4.element.ResultSet

# %%
postcodes
# Out:
# [<strong>2250</strong>,
#  <strong>2320</strong>,
#  <strong>2324</strong>,
#  <strong>2528</strong>,
#  <strong>2557</strong>,
#  <strong>2570</strong>,
#  <strong>2753</strong>,
#  <strong>2756</strong>,
# ...

# %%
postcodes[59].get_text()
# Out:
# '3000, 3002, 3003, 3004, 3005, 3006, 3008, 3011, 3012, 3013, 3015, 3016, 3018, 3019, 3020, 3021, 3022, 3023, 3024, 3025, 3026, 3027, 3028, 3029, 3031, 3032, 3033, 3034, 3036, 3037, 3038, 3039, 3040, 3041, 3042, 3043, 3044, 3045, 3046, 3047, 3048, 3049, 3051, 3052, 3053, 3054, 3055, 3056, 3057, 3058, 3059, 3060, 3061, 3062, 3064, 3065, 3066, 3067, 3068, 3070, 3071, 3072, 3073, 3074, 3075, 3076, 3078, 3079, 3081, 3082, 3083, 3084, 3085, 3087, 3088, 3089, 3090, 3093, 3094, 3095, 3101, 3102, 3103, 3104, 3105, 3106, 3107, 3108, 3109, 3111, 3114, 3116, 3121, 3122, 3123, 3124, 3125, 3126, 3127, 3128, 3129, 3130, 3131, 3132, 3133, 3134, 3135, 3136, 3137, 3138, 3140, 3141, 3142, 3143, 3144, 3145, 3146, 3147, 3148, 3149, 3150, 3151, 3152, 3153, 3155, 3156, 3161, 3162, 3163, 3165, 3166, 3167, 3168, 3169, 3170, 3171, 3172, 3173, 3174, 3175, 3177, 3178, 3179, 3180, 3181, 3182, 3183, 3184, 3185, 3186, 3187, 3188, 3189, 3190, 3191, 3192, 3193, 3194, 3195, 3196, 3197, 3198, 3199, 3200, 3201, 3202, 3
# ...

# %%
postcode_metro = postcodes[59].get_text()
postcode_metro = postcode_metro.split(', ')
postcode_metro
# Out:
# ['3000',
#  '3002',
#  '3003',
#  '3004',
#  '3005',
#  '3006',
#  '3008',
#  '3011',
#  '3012',
#  '3013',
#  '3015',
#  '3016',
#  '3018',
#  '3019',
#  '3020',
#  '3021',
#  '3022',
#  '3023',
#  '3024',
#  '3025',
#  '3026',
#  '3027',
#  '3028',
#  '3029',
#  '3031',
#  '3032',
#  '3033',
#  '3034',
#  '3036',
#  '3037',
#  '3038',
#  '3039',
#  '3040',
#  '3041',
#  '3042',
#  '3043',
#  '3044',
#  '3045',
#  '3046',
#  '3047',
#  '3048',
#  '3049',
#  '3051',
#  '3052',
#  '3053',
#  '3054',
#  '3055',
#  '3056',
#  '3057',
#  '3058',
#  '3059',
#  '3060',
#  '3061',
#  '3062',
#  '3064',
#  '3065',
#  '3066',
#  '3067',
#  '3068',
#  '3070',
#  '3071',
#  '3072',
#  '3073',
#  '3074',
#  '3075',
#  '3076',
#  '3078',
#  '3079',
#  '3081',
#  '3082',
#  '3083',
#  '3084',
#  '3085',
#  '3087',
#  '3088',
#  '3089',
#  '3090',
#  '3093',
#  '3094',
#  '3095',
#  '3101',
#  '3102',
#  '3103',
#  '3104',
#  '3105',
#  '3106',
#  '3107',
#  '3108',
#  '3109',
#  '3111',
# ...

# %%
postcode_metro.append(postcodes[55].get_text())
postcode_metro.append(postcodes[56].get_text())
postcode_metro.append(postcodes[57].get_text())
postcode_metro.append(postcodes[58].get_text())

# %%
postcode_metro
# Out:
# ['3000',
#  '3002',
#  '3003',
#  '3004',
#  '3005',
#  '3006',
#  '3008',
#  '3011',
#  '3012',
#  '3013',
#  '3015',
#  '3016',
#  '3018',
#  '3019',
#  '3020',
#  '3021',
#  '3022',
#  '3023',
#  '3024',
#  '3025',
#  '3026',
#  '3027',
#  '3028',
#  '3029',
#  '3031',
#  '3032',
#  '3033',
#  '3034',
#  '3036',
#  '3037',
#  '3038',
#  '3039',
#  '3040',
#  '3041',
#  '3042',
#  '3043',
#  '3044',
#  '3045',
#  '3046',
#  '3047',
#  '3048',
#  '3049',
#  '3051',
#  '3052',
#  '3053',
#  '3054',
#  '3055',
#  '3056',
#  '3057',
#  '3058',
#  '3059',
#  '3060',
#  '3061',
#  '3062',
#  '3064',
#  '3065',
#  '3066',
#  '3067',
#  '3068',
#  '3070',
#  '3071',
#  '3072',
#  '3073',
#  '3074',
#  '3075',
#  '3076',
#  '3078',
#  '3079',
#  '3081',
#  '3082',
#  '3083',
#  '3084',
#  '3085',
#  '3087',
#  '3088',
#  '3089',
#  '3090',
#  '3093',
#  '3094',
#  '3095',
#  '3101',
#  '3102',
#  '3103',
#  '3104',
#  '3105',
#  '3106',
#  '3107',
#  '3108',
#  '3109',
#  '3111',
# ...

# %%
# Close the browser after scraping
browser.quit()
